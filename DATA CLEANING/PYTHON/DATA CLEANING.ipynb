# %%
# IMPORT PANDAS AND NUMPY
# IMPORT THE DATA FROM DATA SOURCE

import pandas as pd
import numpy as np

Data_Frame = pd.read_excel('/content/sample employee.xls')
Data_Frame

# TO READ TOP FIVE ROWS
Data_Frame.head()

# TO READ LAST FIVE ROWS
Data_Frame.tail()

# TO FIND NULL VALUES

Null_Values = Data_Frame.isna()
Count=Null_Values.sum()               # IT SHOWS HOW MANY NULL VALUES BY COLUMN
Count

# SPECIFIC VALUES FILL INSTEAD OF NULL VALUES

Fill_Null = Data_Frame.fillna(0)
Null_Values = Fill_Null.isna()
Count=Null_Values.sum()
Count

# %%
# TO HANDLE SPECIFIED COLUMNS

import pandas as pd
Data = pd.DataFrame(Data_Frame)
Columns=pd.DataFrame(Data,columns=['Full Name','Age','City'])
Columns.head()

# REMOVE DUPLICATES

Data = pd.DataFrame(Data_Frame)
Sorted_data = Data.drop_duplicates()
Sorted_data

# REMOVE UNWANTED COLUMNS

Data = pd.DataFrame(Data_Frame)
Sorted_Table = Data.drop(['Ethnicity','Age'],axis=1)
Sorted_Table

# AXIS=1 REFERS REMOVE COLUMN IN PANDAS
# AXIS=0 REFERS ROW IN PANDAS

# %%
# COMPLETE DATA CLEANED TABLE

import pandas as pd
import numpy as np

Data_Frame = pd.read_excel('/content/sample employee.xls')
Data_Frame.to_csv('Data_cleaned.csv')         # DATA STORED TO CSV FILE
Data = pd.DataFrame(Data_Frame)
Sorted_data = Data.drop_duplicates()
Sorted_data.to_csv('Data_cleaned.csv')
Data = pd.DataFrame(Data_Frame)
Sorted_Table = Data.drop(['Ethnicity',
                          'Bonus %',
                          'City',
                          'Exit Date'],axis=1)
Sorted_Table.to_csv('Data_cleaned.csv')
pd.read_csv('Data_cleaned.csv')               # READ THE STROED CSV FILE
